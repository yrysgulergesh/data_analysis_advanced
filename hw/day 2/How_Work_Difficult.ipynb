# %% [markdown]
# ```
# # Добро пожаловать в клуб любителей форменной жести!
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Part 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
a = int(input('Введите первое число: '))
b = int(input('Введите второе число: '))
oper = input('Математическая операция: ')
if oper == '+':
  print(a+b)
elif oper == '-':
  print(a-b)
elif oper == '*':
  print(a*b)
elif oper == '/':
  if b != 0:
    print(a/b)
  else:
    print('Иди нафиг! Нельзя делить на 0!')
elif oper == 'mod':
  if b != 0:
    print(a%b)
  else:
    print('Иди нафиг! Нельзя делить на 0!')
elif oper == 'pow':
  print(a**b)
elif oper == 'div':
  if b != 0:
    print(a//b)
  else:
    print('Иди нафиг! Нельзя делить на 0!')
# Out:
# Введите первое число: 1
# Введите второе число: 0
# Математическая операция: mod
# Иди нафиг! Нельзя делить на 0!

# %% [markdown]
# # Part 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
fig = input('What type of figure?')
if fig == 'треугольник':
  a = int(input('a:'))
  b = int(input('b:'))
  c = int(input('c:'))
  p = (a+b+c)/2
  s = round((p*(p-a)*(p-b)*(p-c))**0.5, 2)
elif fig == 'прямоугольник':
  a = int(input('a:'))
  b = int(input('b:'))
  s = a*b
else:
  r = int(input('r:'))
  s = 3.14*r**2
print('Площадь ' + fig + 'a равна ', s)
# Out:
# What type of figure?прямоугольник
# a:2
# b:3
# Площадь прямоугольникa равна  6

# %% [markdown]
# # Part 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Part 5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Part 6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Part 7

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Part 8

# %% [markdown]
# ![image.png](data:image/png;base64,...)
