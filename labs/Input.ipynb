# %%
mes = 'Введите ваш возраст: '
a = int(input(mes))
a
# Out:
# 27

# %%
print(a)
# Out:
# 27

# %%
a
# Out:
# 27

# %%
f = 21.5

# %%
type(a)
# Out:
# int

# %%
f = float(f)

# %%
f
# Out:
# 21.5

# %%
#upper()
#lower()
#capitalize()

s = 'jhgjhsdf77'

s1 = "jhgjhsdf77"

# s2 = 'jhgjhsdf77"

# %%
s
# Out:
# 'jhgjhsdf77'

# %%
s = s.capitalize()

# %%
s.upper()
# Out:
# 'JHGJHSDF77'

# %%
s
# Out:
# 'abcaaa deaf 345'

# %%
name = input().capitalize()

# %%
name
# Out:
# 'Yrysgul'

# %%
s1 = 'ab'
s2 = '_'

# %%
s = 'abcaaa deaf 345'

# %%
s = s.replace(s, s1)

# %%
s
# Out:
# 'ab'

# %%
a = 'abc'
b = 'def'

# %%
name = input()
age = input()
# меня зовут так то и мне столько-то лет
res = 'Меня зовут ' + name + ' и мне ' + age + ' ' + 'лет.'

# %%
print(res)
# Out:
# Меня зовут Yrysgul и мне 100 лет.
